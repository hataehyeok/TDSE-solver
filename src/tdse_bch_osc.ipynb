# %% [markdown]
# This is the simulation code of Bloch Oscillation and Zener Tunneling. The necessary function is defined on `tdse_solver.py` and description is written in `readme_tdse_solver.md`. The below list is each separated simulation.
#
# **1st Cell.** Bloch Oscillation (weak field, no Zener tunneling) via Split-Step Fourier Method
#
# **2nd Cell.** Bloch Oscillation with Zener Tunneling (strong field) via Split-Step Fourier Method
#
# **3rd Cell.** Bloch Oscillation (weak field, no Zener tunneling) via Crank-Nicolson Method
#
# **4th Cell.** Bloch Oscillation with Zener Tunneling (strong field) via Crank-Nicolson Method

# %%
from tdse_solver import *
from helper import *

# %%
run_bloch_simulation(
    a=10, v0=0.05, qE=2*np.pi/1E5, dt=1,
    ngx=20, nbnds=5, k0_center=0, sigma_k=0.04,
    Nc=150, Nx=3999, x_range=(-0.4, 0.6), n_periods=6,
    solver=SplitStepFourier,
    filename='../simulation/bch_osc_tdse_ssfm.mp4',
    frame_skip=100
)
# Out:
# Animation saved to ../simulation/bch_osc_tdse_ssfm.mp4 (600 frames, ~24.0s)

# %%
run_bloch_simulation(
    a=10, v0=0.02, qE=2*np.pi/4000, dt=0.1,
    ngx=20, nbnds=5, k0_center=0, sigma_k=0.04,
    Nc=150, Nx=7999, x_range=(-0.4, 2.0), n_periods=6,
    solver=SplitStepFourier,
    filename='../simulation/bch_osc_tdse_ssfm_zener.mp4',
    frame_skip=40
)
# Out:
# Animation saved to ../simulation/bch_osc_tdse_ssfm_zener.mp4 (599 frames, ~24.0s)

# %%
run_bloch_simulation(
    a=10, v0=0.05, qE=2*np.pi/1E5, dt=1,
    ngx=20, nbnds=5, k0_center=0, sigma_k=0.04,
    Nc=150, Nx=3999, x_range=(-0.4, 0.6), n_periods=6,
    solver=CrankNicolson,
    filename='../simulation/bch_osc_tdse_cn.mp4',
    frame_skip=100
)
# Out:
# Animation saved to ../simulation/bch_osc_tdse_cn.mp4 (600 frames, ~24.0s)

# %%
run_bloch_simulation(
    a=10, v0=0.02, qE=2*np.pi/4000, dt=0.1,
    ngx=20, nbnds=5, k0_center=0, sigma_k=0.04,
    Nc=150, Nx=7999, x_range=(-0.4, 2.0), n_periods=6,
    solver=CrankNicolson,
    filename='../simulation/bch_osc_tdse_cn_zener.mp4',
    frame_skip=40
)
# Out:
# Animation saved to ../simulation/bch_osc_tdse_cn_zener.mp4 (599 frames, ~24.0s)
